# %% [markdown]
# # Task 4: Exploratory Data Analysis-Terrorism
# Aim: To analyze the hot zones of terrorism.
#      What are the security issues and find insights.
# Author:Aamera Shaikh

# %%
#Importing Libraries
import pandas as pd
import numpy as np

# %%
#Reading the csv file
df=pd.read_csv("globalterrorismdb_0718dist.csv" )
pd.set_option('display.max_columns',None)
df.head()
# Out:
# c:\users\azam shaikh\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# ...

# %%
df.shape
# Out:
# (181691, 135)

# %%
#Renaming columns
dict={'iyear':'Year','imonth':'Month','iday':'Day','extended':'Extended','country_txt':'Country','region_txt':'Region','provstate':'State','city':'City','latitude':'Latitude','longitude':'Longitude','summary':'Summary','gname':'Group','attacktype1_txt':'AttackType','targtype1_txt':'Target_Type','target1':'Target','nkill':'Killed','nwound':'Wounded','weaptype1_txt':'Weapon_type','motive':'Motive'}
df.rename(columns=dict,inplace=True)
df.head()
# Out:
#         eventid  Year  Month  Day approxdate  Extended resolution  country  \
# 0  197000000001  1970      7    2        NaN         0        NaN       58
# 1  197000000002  1970      0    0        NaN         0        NaN      130
# 2  197001000001  1970      1    0        NaN         0        NaN      160
# 3  197001000002  1970      1    0        NaN         0        NaN       78
# 4  197001000003  1970      1    0        NaN         0        NaN      101
#
#               Country  region                       Region    State  \
# 0  Dominican Republic       2  Central America & Caribbean      NaN
# 1              Mexico       1                North America  Federal
# 2         Philippines       5               Southeast Asia   Tarlac
# 3              Greece       8               Western Europe   Attica
# 4               Japan       4                    East Asia  Fukouka
#
#             City   Latitude   Longitude  specificity  vicinity location  \
# ...

# %%
#Reducing the columns
df=df[['Year','Month','Day','Extended','Country','Region','State','City','Latitude','Longitude','Summary','Group','AttackType','Target_Type','Target','Killed','Wounded','Weapon_type','Motive']]
df.head()
# Out:
#    Year  Month  Day  Extended             Country  \
# 0  1970      7    2         0  Dominican Republic
# 1  1970      0    0         0              Mexico
# 2  1970      1    0         0         Philippines
# 3  1970      1    0         0              Greece
# 4  1970      1    0         0               Japan
#
#                         Region    State           City   Latitude   Longitude  \
# 0  Central America & Caribbean      NaN  Santo Domingo  18.456792  -69.951164
# 1                North America  Federal    Mexico city  19.371887  -99.086624
# 2               Southeast Asia   Tarlac        Unknown  15.478598  120.599741
# 3               Western Europe   Attica         Athens  37.997490   23.762728
# 4                    East Asia  Fukouka        Fukouka  33.580412  130.396361
#
#   Summary                               Group                      AttackType  \
# 0     NaN                              MANO-D                   Assassination
# ...

# %%
#Looking for datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 19 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   Day          181691 non-null  int64
#  3   Extended     181691 non-null  int64
#  4   Country      181691 non-null  object
#  5   Region       181691 non-null  object
#  6   State        181270 non-null  object
#  7   City         181257 non-null  object
#  8   Latitude     177135 non-null  float64
#  9   Longitude    177134 non-null  float64
#  10  Summary      115562 non-null  object
#  11  Group        181691 non-null  object
#  12  AttackType   181691 non-null  object
#  13  Target_Type  181691 non-null  object
#  14  Target       181055 non-null  object
#  15  Killed       171378 non-null  float64
#  16  Wounded      165380 non-null  float64
#  17  Weapon_type  181691 non-null  object
# ...

# %%
#Understanding data
df.describe()
# Out:
#                 Year          Month            Day       Extended  \
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean     2002.638997       6.467277      15.505644       0.045346
# std        13.259430       3.388303       8.814045       0.208063
# min      1970.000000       0.000000       0.000000       0.000000
# 25%      1991.000000       4.000000       8.000000       0.000000
# 50%      2009.000000       6.000000      15.000000       0.000000
# 75%      2014.000000       9.000000      23.000000       0.000000
# max      2017.000000      12.000000      31.000000       1.000000
#
#             Latitude     Longitude         Killed        Wounded
# count  177135.000000  1.771340e+05  171378.000000  165380.000000
# mean       23.498343 -4.586957e+02       2.403272       3.167668
# std        18.569242  2.047790e+05      11.545741      35.949392
# min       -53.154613 -8.618590e+07       0.000000       0.000000
# ...

# %%
#Looking for missing values
df.isnull().sum()
# Out:
# Year                0
# Month               0
# Day                 0
# Extended            0
# Country             0
# Region              0
# State             421
# City              434
# Latitude         4556
# Longitude        4557
# Summary         66129
# Group               0
# AttackType          0
# Target_Type         0
# Target            636
# Killed          10313
# Wounded         16311
# Weapon_type         0
# Motive         131130
# dtype: int64

# %%
#Removing the missing values
df=df.dropna(axis=0,how='any',thresh=None,inplace=False)

# %%
df.shape
# Out:
# (46556, 19)

# %%
#Checking for missing values
df.isnull().sum()
# Out:
# Year           0
# Month          0
# Day            0
# Extended       0
# Country        0
# Region         0
# State          0
# City           0
# Latitude       0
# Longitude      0
# Summary        0
# Group          0
# AttackType     0
# Target_Type    0
# Target         0
# Killed         0
# Wounded        0
# Weapon_type    0
# Motive         0
# dtype: int64

# %%
#Saving the file on desktop
df.to_csv(r'C:\Users\Azam Shaikh\Desktop\terrorism.csv', index=False)
